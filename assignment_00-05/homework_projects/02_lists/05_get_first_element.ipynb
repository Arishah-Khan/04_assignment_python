# %% [markdown]
# # Problem Statement
#
# Fill out the function get_first_element(lst) which takes in a list lst as a parameter and prints the first element in the list. The list is guaranteed to be non-empty. We've written some code for you which prompts the user to input the list one element at a time.

# %%
def get_first_element(lst):
    """Prints the first element of a provided list."""
    if lst:
        print("\nFirst element:", lst[0])
    else:
        print("\nThe list is empty.")

def get_list_from_user():
    """Prompts the user to enter elements one by one and returns the final list."""
    lst = []
    while True:
        elem = input("Enter a list element (or press Enter to finish): ")
        if elem == "":
            break
        lst.append(elem)
    return lst

def main():
    user_list = get_list_from_user()
    get_first_element(user_list)
    print("\nProgram finished.")

if __name__ == '__main__':
    main()
# Out:
# Enter a list element (or press Enter to finish): red
# Enter a list element (or press Enter to finish): yellow
# Enter a list element (or press Enter to finish): green
# Enter a list element (or press Enter to finish): purple
# Enter a list element (or press Enter to finish):
#
# First element: red
#
# Program finished.
