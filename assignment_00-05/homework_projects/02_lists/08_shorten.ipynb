# %% [markdown]
# # Problem Statement
#
# Fill out the function shorten(lst) which removes elements from the end of lst, which is a list, and prints each item it removes until lst is MAX_LENGTH items long. If lst is already shorter than MAX_LENGTH you should leave it unchanged. We've written a main() function for you which gets a list and passes it into your function once you run the program. For the autograder to pass you will need MAX_LENGTH to be 3, but feel free to change it around to test your program.

# %%
def shorten(lst, max_length):
    """Removes elements from the end of the list until its length is max_length."""
    while len(lst) > max_length:
        removed_element = lst.pop()
        print("Removing:", removed_element)

def main():
    max_length = 4
    colourList = []

    while True:
        user_input = input("Enter the element (or press Enter to finish): ")

        if user_input == "":
            break

        colourList.append(user_input)

    print("Original list:", colourList)

    shorten(colourList, max_length)

    print("Final list:", colourList)

if __name__ == "__main__":
    main()
# Out:
# Enter the element (or press Enter to finish): 5
# Enter the element (or press Enter to finish): 6
# Enter the element (or press Enter to finish): 4
# Enter the element (or press Enter to finish): 6
# Enter the element (or press Enter to finish): 3
# Enter the element (or press Enter to finish): 2
# Enter the element (or press Enter to finish): 1
# Enter the element (or press Enter to finish): 7
# Enter the element (or press Enter to finish): 8
# Enter the element (or press Enter to finish): 9
# Enter the element (or press Enter to finish): 33
# Enter the element (or press Enter to finish): 22
# Enter the element (or press Enter to finish): 12
# Enter the element (or press Enter to finish): 54
# Enter the element (or press Enter to finish):
# Original list: ['5', '6', '4', '6', '3', '2', '1', '7', '8', '9', '33', '22', '12', '54']
# Removing: 54
# Removing: 12
# Removing: 22
# Removing: 33
# Removing: 9
# Removing: 8
# Removing: 7
# Removing: 1
# Removing: 2
# Removing: 3
# ...
