# %% [markdown]
# # Problem Statement
#
# Write a program which continuously asks the user to enter values which are added one by one into a list. When the user presses enter without typing anything, print the list.
#
# Here's a sample run (user input is in blue):
#
# Enter a value: 1 Enter a value: 2 Enter a value: 3 Enter a value: Here's the list: ['1', '2', '3']

# %%
def main():
    user_list = []

    while True:
        print("\nOptions:")
        print("1 - Add element to the list")
        print("2 - View the list and exit")

        choice = input("Enter your choice (1 or 2): ")

        if choice == "1":
            value = input("Enter a value: ")
            user_list.append(value)
        elif choice == "2":
            if not user_list:
                print("The list is empty.")
            else:
                print("\nHere's the final list:", user_list)
            break
        else:
            print("Invalid choice! Please enter 1 or 2.")

if __name__ == "__main__":
    main()
# Out:
# Options:
# 1 - Add element to the list
# 2 - View the list and exit
# Enter your choice (1 or 2): 3
# Invalid choice! Please enter 1 or 2.
#
# Options:
# 1 - Add element to the list
# 2 - View the list and exit
# Enter your choice (1 or 2): 4
# Invalid choice! Please enter 1 or 2.
#
# Options:
# 1 - Add element to the list
# 2 - View the list and exit
# Enter your choice (1 or 2): 5
# Invalid choice! Please enter 1 or 2.
#
# Options:
# 1 - Add element to the list
# 2 - View the list and exit
# Enter your choice (1 or 2): 1
# Enter a value: 3
#
# Options:
# 1 - Add element to the list
# 2 - View the list and exit
# Enter your choice (1 or 2): 1
# Enter a value: 23
#
# Options:
# 1 - Add element to the list
# 2 - View the list and exit
# Enter your choice (1 or 2): 2
#
# Here's the final list: ['3', '23']
