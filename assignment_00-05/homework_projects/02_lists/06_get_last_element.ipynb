# %% [markdown]
# # Problem Statement
#
# Fill out the function get_last_element(lst) which takes in a list lst as a parameter and prints the last element in the list. The list is guaranteed to be non-empty, but there are no guarantees on its length.
#
# (Note. The concept of immutable/mutable data types is called mutability. Be careful because different programming languages have different rules regarding mutability!)

# %%
def get_last_element(lst):
    if len(lst) == 0:
        print("List is empty")
        return None

    return lst[-1]

def get_user_element():
    lst = []

    while True:
        user_input = input("Enter a list element one by one, or press Enter to stop: ")
        if user_input == "":
            break
        lst.append(user_input)

    return lst

def main():
    user_list = get_user_element()
    last_element = get_last_element(user_list)

    if last_element is not None:
        print("Last element:", last_element)
        print("Program Done5")

if __name__ == '__main__':
    main()
# Out:
# Enter a list element one by one, or press Enter to stop: 3
# Enter a list element one by one, or press Enter to stop: 4
# Enter a list element one by one, or press Enter to stop:
# Last element: 4
# Program Done
