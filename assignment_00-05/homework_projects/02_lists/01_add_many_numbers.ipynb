# %% [markdown]
# # Problem Statement
#
# Write a function that takes a list of numbers and returns the sum of those numbers.

# %%
def main(numbers):
    count = 0
    for num in numbers:
        count += num
    return count

if __name__ == "__main__":
    totalValue = main([3, 5, 9, 2, 3])
    print(totalValue)
# Out:
# 22
